# %%
import pandas as pd
import numpy as np
# Show all columns
pd.set_option('display.max_columns', None)

data = pd.read_csv('C:/Users/mathi/OneDrive/Skrivebord/2_Sem_Kand/Projekt_Kandidat2/DataPrep.csv')
data
# Out:
#       Unnamed: 0                        id  device        from          to  \
# 0              0  5f7e0ab04a207808e008dac6  1EFD48  1602086420  1602095731
# 1              1  5f7ec3b3765d9b08e03c5211  1EFD48  1602104992  1602143148
# 2              2  5f7f6eae2eb84708e0d88f54  1EFD48  1602175075  1602186881
# 3              3  5f7ff574b2cf6908e0d28fcf  1EFD48  1602191290  1602221363
# 4              4  5f81553968df9708e069c7b1  1EFD48  1602278207  1602311453
# ...          ...                       ...     ...         ...         ...
# 5590        5590  63fc11f76984a917887113e4  1C6994  1677443559  1677464007
# 5591        5591  63fd6a99c578671848ceca64  1C6994  1677533318  1677552131
# 5592        5592  63febaf55a97a71848062b68  1C6994  1677616071  1677638369
# 5593        5593  640001b55d34f61848e4dbba  1C6994  1677702052  1677721997
# 5594        5594  64015d96c4832e1848f376ad  1C6994  1677790627  1677811024
#
#       avg_hr  avg_rr  avg_act  \
# 0       58.6     9.1    285.9
# ...

# %% [markdown]
# ### Analyse af calc_data

# %%
# Show only calc_data, patient_ID and from_datetime
data = data[['calc_data', 'patient_ID', 'from_datetime']]
data
# Out:
#                                               calc_data  patient_ID  \
# 0     [[1602086424,null,null,757],[1602086428,null,n...         431
# 1     [[1602104996,null,null,110],[1602105000,null,n...         431
# 2     [[1602175076,null,null,86],[1602175080,null,nu...         431
# 3     [[1602191292,null,null,80],[1602191296,null,nu...         431
# 4     [[1602278210,null,null,172],[1602278214,null,n...         431
# 5     [[1602316073,null,null,650],[1602316077,null,n...         431
# 6     [[1602347703,null,null,315],[1602347707,null,n...         431
# 7     [[1602536986,null,null,199],[1602536990,null,n...         431
# 8     [[1602590867,null,null,8614],[1602590871,null,...         431
# 9     [[1602606191,null,null,209],[1602606195,null,n...         431
# 10    [[1602709902,null,null,307],[1602709906,null,n...         431
# 11    [[1602796257,null,null,212],[1602796261,null,n...         431
# 12    [[1602883113,null,null,379],[1602883117,null,n...         431
# ...
