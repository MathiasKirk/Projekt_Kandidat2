# %% [markdown]
# ## Data

# %%
# Import 
import pandas as pd
import numpy as np

####### pip install openpyxl

# convert xlsx to csv
df_FP1 = pd.read_excel('FP1_HF_DataValues.xlsx')
df_FP2 = pd.read_excel('FP2_HF_DataValues.xlsx')

df_FP1
# Out:
#         SubjectId          TimeMeasrd  DataSrcId  DataTypeId  \
# 0              49 2017-01-05 11:43:30          2           2
# 1              49 2017-01-05 11:43:30          2           3
# 2              49 2017-01-05 11:43:30          2           4
# 3              49 2017-01-05 23:59:59          3           5
# 4              49 2017-01-06 11:24:25          2           1
# ...           ...                 ...        ...         ...
# 135847        393 2018-12-29 23:59:59          3           5
# 135848        393 2018-12-30 20:20:01          3           5
# 135849        393 2019-04-23 11:40:00          1           2
# 135850        393 2019-04-23 11:40:00          1           3
# 135851        393 2019-04-23 11:40:00          1           4
#
#                DataTypeLabel   Value    Unit
# 0        Blodtryk, Systolisk   153.0    mmHg
# 1       Blodtryk, Diastolisk    84.0    mmHg
# 2                       Puls    66.0     BPM
# 3                     Skridt  8262.0  skridt
# ...

# %%
df_FP2
# Out:
#        SubjectId           TimeMeasrd  DataSrcId  DataTypeId  \
# 0            431  2020-10-07 16:45:46          7           2
# 1            431  2020-10-07 16:45:46          7           3
# 2            431  2020-10-07 16:45:46          7           4
# 3            431  2020-10-07 16:48:19          7           1
# 4            431  2020-10-07 16:48:46          7           1
# ...          ...                  ...        ...         ...
# 27297        554  2023-02-28 05:27:23          7           1
# 27298        554  2023-03-01 04:36:28          7           1
# 27299        554  2023-03-01 04:38:02          7           2
# 27300        554  2023-03-01 04:38:02          7           3
# 27301        554  2023-03-01 04:38:02          7           4
#
#               DataTypeLabel       Value  Unit
# 0       Blodtryk, Systolisk  160.000000  mmHg
# 1      Blodtryk, Diastolisk   69.000000  mmHg
# 2                      Puls   65.000000   BPM
# ...

# %% [markdown]
# ### Emfit data

# %%
# load Emfit folder that have a folder Sbt152 
FileLokation = 'C:\Users\mathi\OneDrive\Skrivebord\2. Sem Kand\Projekt_Kandidat2\Projekt_Kandidat2\Emfit\Sbt152'

# Display FileLokation folder that contaion .log files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # load Emfit folder
# ----> 2 df_EM = pd.read_csv('Emfit.csv')
#       3 df_EM
#
# File c:\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
