# %%
# Import Pandas
import pandas as pd

# Show all columns
pd.set_option('display.max_columns', None)

# Read Data.csv
data = pd.read_csv('C:/Users/mathi/OneDrive/Skrivebord/2_Sem_Kand/Projekt_Kandidat2/Data.csv')

data
# Out:
#        Unnamed: 0                        id  device  user_id        from  \
# 0               0  59e9a40bd41d8c0045e62fc9  1F0B95      0.0  1508404086
# 1               1  59ec7241d41d8c004569fae0  1F0B95      0.0  1508627624
# 2               2  59edb8e2d41d8c0045a1f035  1F0B95      0.0  1508717933
# 3               3  59eedcc8d41d8c0045c86f88  1F0B95      0.0  1508799247
# 4               4  59ef153ed41d8c00450acbc8  1F0B95      0.0  1508831740
# ...           ...                       ...     ...      ...         ...
# 21866       21866  63fe92952f91ec18484a1c33  11EC56      NaN  1677620134
# 21867       21867  63fef84eef176518489aba2c  11EC56      NaN  1677620134
# 21868       21868  64002e9c82af5e1848c39a00  11EC56      NaN  1677707752
# 21869       21869  640142b5c0869a1848a5de45  11EC56      NaN  1677794122
# 21870       21870  640185861eab4c1848f78672  11EC56      NaN  1677794122
#
#                to  avg_hr  avg_rr  avg_act  \
# 0      1508484019     NaN     NaN      0.0
# 1      1508667920    63.4    12.5    130.7
# 2      1508751497    64.3    12.8    115.9
# 3      1508826256    65.7    13.2     94.5
# 4      1508840683    64.9    14.4    160.2
# ...           ...     ...     ...      ...
# 21866  1677627980    61.2    16.1    608.1
# 21867  1677654035    60.2    15.8    468.6
# 21868  1677733460    61.7    16.6    451.9
# 21869  1677804160    59.5    15.3    453.4
# 21870  1677821258    58.3    15.6    439.2
#
#                                                calc_data  sleep_score  \
# 0      [[1508483920,null,null,0],[1508483928,null,nul...          NaN
# 1      [[1508627625,null,null,60],[1508627629,null,nu...        112.0
# 2      [[1508717936,null,null,14],[1508717940,72,null...         84.0
# 3      [[1508799251,56,null,37],[1508799255,56,null,4...         78.0
# 4      [[1508831743,60,null,19],[1508831747,58,null,1...         15.0
# ...                                                  ...          ...
# 21866  [[1677620138,null,null,405],[1677620142,null,n...         18.0
# 21867  [[1677620138,null,null,405],[1677620142,null,n...         89.0
# 21868  [[1677707755,null,null,9560],[1677707759,null,...         68.0
# 21869  [[1677794126,null,null,6057],[1677794130,null,...         27.0
# 21870  [[1677794126,null,null,6057],[1677794130,null,...         71.0
#
#        duration  duration_in_bed  duration_awake  duration_in_sleep  \
# 0         79933            79933             NaN                NaN
# 1         40296            39450          3120.0            37170.0
# 2         33564            32075          5580.0            27990.0
# 3         27009            27009          3000.0            24000.0
# 4          8943             8855          2880.0             6060.0
# ...         ...              ...             ...                ...
# 21866      7846             7846          1920.0             5910.0
# 21867     33901            33557          4200.0            29700.0
# 21868     25708            25642          3420.0            22290.0
# 21869     10038            10038          1320.0             8700.0
# 21870     27136            27019          2940.0            24180.0
#
#        duration_in_rem  duration_in_light  duration_in_deep  \
# 0                  NaN                NaN               NaN
# 1              10560.0            21720.0            4890.0
# 2               5430.0            17250.0            5310.0
# 3               2670.0            15120.0            6210.0
# 4               1050.0             4170.0             840.0
# ...                ...                ...               ...
# 21866           1140.0             3390.0            1380.0
# 21867           7980.0            17430.0            4290.0
# 21868           7080.0            12150.0            3060.0
# 21869           2850.0             4590.0            1260.0
# 21870           8250.0            13290.0            2640.0
#
#        duration_sleep_onset  bedexit_duration  \
# 0                       NaN                 0
# 1                     840.0               846
# 2                    1710.0              1489
# 3                    1980.0                 0
# 4                    1380.0                88
# ...                     ...               ...
# 21866                 840.0                 0
# 21867                 840.0               344
# 21868                1830.0                66
# 21869                1050.0                 0
# 21870                1020.0               117
#
#                                               sleep_data  bedexit_count  \
# 0                                                    NaN              0
# 1      [[1508627640,4],[1508628450,2],[1508629770,1],...              1
# 2      [[1508717951,4],[1508719631,2],[1508720471,1],...              2
# 3      [[1508799266,4],[1508801216,2],[1508802026,1],...              0
# 4      [[1508831758,4],[1508833108,2],[1508833768,4],...              1
# ...                                                  ...            ...
# 21866  [[1677620153,4],[1677620963,2],[1677623063,1],...              0
# 21867  [[1677620153,4],[1677620963,2],[1677623033,1],...              2
# 21868  [[1677707770,4],[1677709570,2],[1677711400,3],...              1
# 21869  [[1677794141,4],[1677795161,2],[1677796631,1],...              0
# 21870  [[1677794141,4],[1677795131,2],[1677796601,1],...              1
#
#                                             bedexit_data  tossnturn_count  \
# 0                                                      ]                0
# 1                              [[1508644545,1508643699]]              260
# 2      [[1508745172,1508744839],[1508741440,1508740284]]              196
# 3                                                      ]              153
# 4                              [[1508834628,1508834540]]               68
# ...                                                  ...              ...
# 21866                                                NaN              102
# 21867  [[1677653086,1677652879],[1677628117,1677627980]]              274
# 21868                          [[1677733448,1677733382]]              192
# 21869                                                NaN               71
# 21870                          [[1677804277,1677804160]]              184
#
#                                           tossnturn_data  from_gmt_offset  \
# 0                                                    NaN              180
# 1      [1508627629,1508627709,1508627973,1508628229,1...              180
# 2      [1508717972,1508718124,1508718160,1508718176,1...              180
# 3      [1508799291,1508799315,1508799371,1508799391,1...              180
# 4      [1508831799,1508831847,1508832067,1508832331,1...              180
# ...                                                  ...              ...
# 21866  [1677620146,1677620162,1677620178,1677620194,1...              120
# 21867  [1677620146,1677620162,1677620178,1677620194,1...              120
# 21868  [1677707779,1677707795,1677707827,1677707847,1...              120
# 21869  [1677794138,1677794154,1677794178,1677794198,1...              120
# 21870  [1677794138,1677794154,1677794178,1677794198,1...              120
#
#        min_hr  max_hr  min_rr  max_rr  fm_count fm_data  awakenings  \
# 0         NaN     NaN     NaN     NaN         0     NaN         NaN
# 1        45.0   103.0     6.0    21.0         0     NaN         3.0
# 2        54.0    78.0     7.0    19.0         0     NaN         2.0
# 3        55.0   115.0     8.0    26.0         0     NaN         0.0
# 4        48.0    95.0     8.0    18.0         0     NaN         1.0
# ...       ...     ...     ...     ...       ...     ...         ...
# 21866    54.0   114.0    10.0    26.0         0     NaN         0.0
# 21867    49.0   126.0    10.0    26.0         0     NaN         1.0
# 21868    49.0   125.0    12.0    26.0         0     NaN         0.0
# 21869    55.0    72.0    13.0    26.0         0     NaN         0.0
# 21870    49.0   117.0    13.0    26.0         0     NaN         3.0
#
#                                                 hrv_data  hrv_score  hrv_lf  \
# 0                                                    NaN        0.0     0.0
# 1      [[42.4,24.5,-17.9,0.58,-1.66],[47.6,32.1,-15.5...       35.0    45.0
# 2      [[32.7,40.1,7.4,1.23,0.80],[34.5,38.9,4.4,1.13...       50.0    44.0
# 3      [[33.1,32.3,-0.8,0.98,-0.11],[34.0,35.8,1.7,1....       42.0    49.0
# 4      [[38.6,50.7,12.2,1.32,4.98],[40.7,48.1,7.4,1.1...       69.0    38.0
# ...                                                  ...        ...     ...
# 21866  [[23.6,38.5,14.9,1.63,9.61],[30.4,31.7,1.4,1.0...       46.0    25.0
# 21867  [[35.0,21.7,-13.3,0.62,-1.55],[29.0,21.6,-7.4,...       25.0    32.0
# 21868  [[70.7,31.1,-39.6,0.44,-6.49],[69.1,39.1,-30.0...       44.0    33.0
# 21869  [[9.4,68.0,58.6,7.27,25.43],[26.4,47.9,21.5,1....       77.0    36.0
# 21870  [[43.6,28.7,-14.8,0.66,-2.11],[26.6,22.1,-4.5,...       31.0    31.0
#
#        hrv_hf                                     hrv_rmssd_data  \
# 0         0.0                                                 []
# 1        55.0  [[1508628794,47,42,58,0,0],[1508629694,50,37,6...
# 2        56.0  [[1508718023,57,51,49,0,0],[1508719643,48,46,5...
# 3        51.0  [[1508799877,28,29,71,0,0],[1508800237,30,30,7...
# 4        62.0  [[1508831830,51,29,71,0,0],[1508832190,29,40,6...
# ...       ...                                                ...
# 21866    75.0  [[1677621124,21,29,71,0,680],[1677621665,22,28...
# 21867    68.0  [[1677621124,22,29,71,0,680],[1677621665,22,28...
# 21868    67.0  [[1677709822,54,27,73,0,188],[1677710002,60,27...
# 21869    64.0  [[1677795293,25,51,49,0,107],[1677795473,24,46...
# 21870    69.0  [[1677795293,26,48,52,0,104],[1677795473,25,44...
#
#        hrv_rmssd_evening  hrv_rmssd_morning  temp_v1_uid  patient_ID
# 0                    NaN                NaN          0.0         152
# 1                   42.4               24.5          0.0         152
# 2                   32.7               40.1          0.0         152
# 3                   33.1               32.3          0.0         152
# 4                   38.6               50.7          0.0         152
# ...                  ...                ...          ...         ...
# 21866               23.6               38.5          NaN         586
# 21867               35.0               21.7          NaN         586
# 21868               70.7               31.1          NaN         586
# 21869                9.4               68.0          NaN         586
# 21870               43.6               28.7          NaN         586
#
# [21871 rows x 42 columns]

# %%
# Read Data.csv
df_patientInfo = pd.read_excel('Data_om_patienter.xlsx')
# Remove 'subject_ID' == Gennemsnit
df_patientInfo = df_patientInfo[df_patientInfo.subject_ID != 'Gennemsnit']

df_patientInfo.tail(5)
# Out:
#    subject_ID   FPx EF_number emfit_device_id  age_baseline  gender  \
# 30        539  38.0     EF38g          1C6930          74.0     0.0
# 31        545  41.0     EF33g          1C6FEE          48.0     0.0
# 32        548  40.0     EF39g          1C6943          60.0     0.0
# 33        552  42.0     EF41g          1C6FF8          65.0     0.0
# 34        554  43.0     EF36g          1C6994          74.0     0.0
#
#     NYHA_baseline  ef_titration  ef_rehabilitation  ef_finished  \
# 30            2.0          30.0               35.0          NaN
# 31            2.0          35.0                NaN         45.0
# 32            2.0          25.0                NaN          NaN
# 33            2.0          20.0                NaN          NaN
# 34            2.0          20.0                NaN          NaN
#
#     weight_baseline  height_baseline  bp_sys_baseline  bp_dia_baseline  \
# 30            107.0            176.0            116.0             74.0
# 31            132.0            190.0            144.0             93.0
# 32            107.5            178.0            108.0             73.0
# 33            100.0            178.0            120.0             66.0
# 34             74.0            183.0            116.0             72.0
#
#     heart_rate_baseline       first_measure        last_measure  Total_days  \
# 30                 89.0                 NaT                 NaT         NaN
# 31                 63.0 2022-12-14 05:03:54 2023-03-07 05:42:10   83.026574
# 32                 81.0 2022-12-14 07:05:02 2022-12-25 19:57:03   11.536123
# 33                 65.0 2022-12-22 04:07:21 2023-03-07 05:54:52   75.074664
# 34                 74.0 2022-12-22 04:42:08 2023-03-07 04:15:45   74.981678
#
#       Beskrivelse
# 30  Har pacemaker
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN

# %% [markdown]
# ### Set Emfit & FP2 sammen

# %%
# Make a list of unique values in the column 'subject_ID'
unique_subject_ID = df_patientInfo['subject_ID'].unique()
# print(unique_subject_ID) # [431 435 440 448 451 453 454 457 459 462 465 468 469 477 478 483 485 492
#  # 494 495 499 504 510 513 515 516 518 520 524 526 539 545 548 552 554]

# # Print unique values in the column 'patient_ID'
# unique_patient_ID = data['patient_ID'].unique() 
# print(unique_patient_ID)  # [152 258 261 264 271 283 285 286 294 299 300 301 318 323 327 329 332 342
#  350 352 353 360 361 376 383 386 402 403 404 405 406 407 408 409 410 411
#  412 413 414 415 416 417 418 419 420 421 431 435 440 448 451 454 459 462
#  465 468 469 477 485 492 494 495 504 510 513 515 516 520 524 526 545 548
#  552 554 560 563 564 569 571 583 586]

# # Which values in unique_patient_ID are not in unique_subject_ID
# print(set(unique_patient_ID) - set(unique_subject_ID))

# Only keep the values in data['patient_ID'] that are in unique_subject_ID
data = data[data['patient_ID'].isin(unique_subject_ID)]


# For loop through the list and where unique_subject_ID is == patient_ID in dataframe data then make new column age_baseline	gender	NYHA_baseline	ef_titration	ef_rehabilitation	ef_finished	weight_baseline	height_baseline	bp_sys_baseline	bp_dia_baseline	heart_rate_baseline and add the values from the dataframe df_patientInfo

for i in unique_subject_ID:
    data.loc[data['patient_ID'] == i, 'AGEBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'age_baseline'].values[0]
    data.loc[data['patient_ID'] == i, 'GENDER'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'gender'].values[0]
    data.loc[data['patient_ID'] == i, 'NYHABL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'NYHA_baseline'].values[0]
    data.loc[data['patient_ID'] == i, 'EFTITBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'ef_titration'].values[0]
    data.loc[data['patient_ID'] == i, 'EJREHABBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'ef_rehabilitation'].values[0]
    data.loc[data['patient_ID'] == i, 'EJFINISHBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'ef_finished'].values[0]
    data.loc[data['patient_ID'] == i, 'WEIGHTBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'weight_baseline'].values[0]
    data.loc[data['patient_ID'] == i, 'HEIGHTBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'height_baseline'].values[0]
    data.loc[data['patient_ID'] == i, 'BPSYSBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'bp_sys_baseline'].values[0]
    data.loc[data['patient_ID'] == i, 'BPDIABL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'bp_dia_baseline'].values[0]
    data.loc[data['patient_ID'] == i, 'HRB'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'heart_rate_baseline'].values[0]

data

# # Print data for patient_ID == 524
# data.loc[data['patient_ID'] == 524]

# # Save as new csv file
# data.to_csv('DataPrep.csv', index=False)
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'AGEBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'age_baseline'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'GENDER'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'gender'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'NYHABL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'NYHA_baseline'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'EFTITBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'ef_titration'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'EJREHABBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'ef_rehabilitation'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'EJFINISHBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'ef_finished'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'WEIGHTBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'weight_baseline'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'HEIGHTBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'height_baseline'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'BPSYSBL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'bp_sys_baseline'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'BPDIABL'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'bp_dia_baseline'].values[0]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_4236\154109309.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['patient_ID'] == i, 'HRB'] = df_patientInfo.loc[df_patientInfo['subject_ID'] == i, 'heart_rate_baseline'].values[0]
#        Unnamed: 0                        id  device  user_id        from  \
# 16201       16201  5f7e0ab04a207808e008dac6  1EFD48      NaN  1602086420
# 16202       16202  5f7ec3b3765d9b08e03c5211  1EFD48      NaN  1602104992
# 16203       16203  5f7f6eae2eb84708e0d88f54  1EFD48      NaN  1602175075
# 16204       16204  5f7ff574b2cf6908e0d28fcf  1EFD48      NaN  1602191290
# 16205       16205  5f81553968df9708e069c7b1  1EFD48      NaN  1602278207
# ...           ...                       ...     ...      ...         ...
# 21791       21791  63fc11f76984a917887113e4  1C6994      NaN  1677443559
# 21792       21792  63fd6a99c578671848ceca64  1C6994      NaN  1677533318
# 21793       21793  63febaf55a97a71848062b68  1C6994      NaN  1677616071
# 21794       21794  640001b55d34f61848e4dbba  1C6994      NaN  1677702052
# 21795       21795  64015d96c4832e1848f376ad  1C6994      NaN  1677790627
#
#                to  avg_hr  avg_rr  avg_act  \
# 16201  1602095731    58.6     9.1    285.9
# 16202  1602143148    62.9    16.4    313.6
# 16203  1602186881    58.8     7.8    134.1
# 16204  1602221363    59.6    16.2    268.9
# 16205  1602311453    60.3    16.1    285.7
# ...           ...     ...     ...      ...
# 21791  1677464007    68.7    15.6    372.2
# 21792  1677552131    63.2    15.4    317.2
# 21793  1677638369    69.1    15.5    204.5
# 21794  1677721997    64.8    15.4    434.6
# 21795  1677811024    61.9    15.6    327.5
#
#                                                calc_data  sleep_score  \
# 16201  [[1602086424,null,null,757],[1602086428,null,n...         18.0
# 16202  [[1602104996,null,null,110],[1602105000,null,n...         84.0
# 16203  [[1602175076,null,null,86],[1602175080,null,nu...         23.0
# 16204  [[1602191292,null,null,80],[1602191296,null,nu...         74.0
# 16205  [[1602278210,null,null,172],[1602278214,null,n...         77.0
# ...                                                  ...          ...
# 21791  [[1677443563,null,null,248],[1677443567,null,n...         55.0
# 21792  [[1677533321,null,null,4],[1677533325,null,nul...         47.0
# 21793  [[1677616073,null,null,0],[1677616077,null,nul...         68.0
# 21794  [[1677702056,null,null,23313],[1677702060,null...         57.0
# 21795  [[1677790631,null,null,256],[1677790635,null,n...         63.0
#
#        duration  duration_in_bed  duration_awake  duration_in_sleep  \
# 16201      9311             9311          2430.0             6870.0
# 16202     38156            38156         10110.0            27990.0
# 16203     11806            11806          3570.0             8220.0
# 16204     30073            28603          4710.0            25350.0
# 16205     33246            31364          7920.0            25320.0
# ...         ...              ...             ...                ...
# 21791     20448            20272          2490.0            17940.0
# 21792     18813            18459          3120.0            15690.0
# 21793     22298            22236           990.0            21300.0
# 21794     19945            19945          1740.0            18210.0
# 21795     20397            20397           960.0            19440.0
#
#        duration_in_rem  duration_in_light  duration_in_deep  \
# 16201           1740.0             4380.0             750.0
# 16202           4830.0            16440.0            6720.0
# 16203           1680.0             5040.0            1500.0
# 16204           3960.0            16800.0            4590.0
# 16205           4080.0            14700.0            6540.0
# ...                ...                ...               ...
# 21791           4740.0            10170.0            3030.0
# 21792           4320.0             8760.0            2610.0
# 21793           4260.0            13140.0            3900.0
# 21794           6390.0             9390.0            2430.0
# 21795           4920.0            11070.0            3450.0
#
#        duration_sleep_onset  bedexit_duration  \
# 16201                1230.0                 0
# 16202                1500.0                 0
# 16203                2130.0                 0
# 16204                1680.0              1470
# 16205                1620.0              1882
# ...                     ...               ...
# 21791                 660.0               176
# 21792                 720.0               354
# 21793                 630.0                62
# 21794                 870.0                 0
# 21795                 780.0                 0
#
#                                               sleep_data  bedexit_count  \
# 16201  [[1602086439,4],[1602087639,2],[1602089829,1],...              0
# 16202  [[1602105011,4],[1602106481,2],[1602107231,1],...              0
# 16203  [[1602175091,4],[1602177191,2],[1602178391,1],...              0
# 16204  [[1602191307,4],[1602192957,2],[1602195057,1],...              2
# 16205  [[1602278225,4],[1602279815,2],[1602280805,1],...              3
# ...                                                  ...            ...
# 21791  [[1677443578,4],[1677444208,2],[1677445108,3],...              1
# 21792  [[1677533336,4],[1677534026,2],[1677535556,1],...              2
# 21793  [[1677616088,4],[1677616688,2],[1677617228,3],...              1
# 21794  [[1677702071,4],[1677702911,2],[1677704021,3],...              0
# 21795  [[1677790646,4],[1677791396,2],[1677792596,3],...              0
#
#                                             bedexit_data  tossnturn_count  \
# 16201                                                NaN               75
# 16202                                                NaN              299
# 16203                                                NaN               66
# 16204  [[1602221090,1602220063],[1602211152,1602210709]]              167
# 16205  [[1602309892,1602308800],[1602305244,160230482...              327
# ...                                                  ...              ...
# 21791                          [[1677460017,1677459841]]              129
# 21792  [[1677551292,1677551100],[1677533585,1677533423]]               74
# 21793                          [[1677616157,1677616095]]               64
# 21794                                                NaN               82
# 21795                                                NaN               73
#
#                                           tossnturn_data  from_gmt_offset  \
# 16201  [1602086436,1602086496,1602086512,1602086528,1...              180
# 16202  [1602105000,1602105020,1602105084,1602105120,1...              180
# 16203  [1602175096,1602175112,1602175128,1602175156,1...              180
# 16204  [1602191520,1602191732,1602191748,1602191780,1...              180
# 16205  [1602278262,1602278526,1602278550,1602278566,1...              180
# ...                                                  ...              ...
# 21791  [1677443579,1677443591,1677443607,1677443623,1...              120
# 21792  [1677533589,1677533613,1677533625,1677533641,1...              120
# 21793  [1677616105,1677616177,1677616253,1677616285,1...              120
# 21794  [1677702060,1677702076,1677702128,1677702156,1...              120
# 21795  [1677790643,1677790683,1677790699,1677790735,1...              120
#
#        min_hr  max_hr  min_rr  max_rr  fm_count  \
# 16201    51.0   110.0     4.0    20.0         0
# 16202    49.0   122.0     5.0    24.0         3
# 16203    53.0    77.0     4.0    20.0         0
# 16204    51.0   120.0     7.0    26.0         0
# 16205    51.0   128.0     6.0    26.0         1
# ...       ...     ...     ...     ...       ...
# 21791    52.0    97.0    12.0    26.0         0
# 21792    48.0    90.0    13.0    19.0         0
# 21793    56.0    79.0     9.0    20.0         0
# 21794    51.0   121.0    12.0    19.0         0
# 21795    48.0    97.0    13.0    26.0         0
#
#                                   fm_data  awakenings  \
# 16201                                 NaN         0.0
# 16202  [1602126450,1602129851,1602134789]         0.0
# 16203                                 NaN         0.0
# 16204                                 NaN         2.0
# 16205                        [1602285137]         2.0
# ...                                   ...         ...
# 21791                                 NaN         1.0
# 21792                                 NaN         1.0
# 21793                                 NaN         0.0
# 21794                                 NaN         0.0
# 21795                                 NaN         0.0
#
#                                                 hrv_data  hrv_score  hrv_lf  \
# 16201  [[36.5,33.5,-2.9,0.92,-1.95],[36.1,32.6,-3.4,0...       48.0    15.0
# 16202  [[55.4,51.9,-3.5,0.94,-0.46],[52.4,48.8,-3.7,0...       60.0    21.0
# 16203  [[67.0,35.3,-31.7,0.53,-23.50],[49.0,49.0,0.0,...       70.0    36.0
# 16204  [[43.2,4.7,-38.5,0.11,-5.19],[39.5,36.2,-3.2,0...       36.0    19.0
# 16205  [[52.4,30.4,-21.9,0.58,-2.75],[48.6,30.0,-18.6...       43.0    18.0
# ...                                                  ...        ...     ...
# 21791  [[26.5,25.6,-0.9,0.97,-0.17],[26.0,25.6,-0.3,0...       42.0    57.0
# 21792  [[31.2,24.2,-7.1,0.77,-1.58],[33.0,29.2,-3.8,0...       33.0    53.0
# 21793  [[36.2,15.7,-20.5,0.43,-3.51],[37.0,21.5,-15.5...       28.0    55.0
# 21794  [[28.2,17.7,-10.4,0.63,-2.09],[23.8,20.4,-3.4,...       24.0    60.0
# 21795  [[19.0,25.6,6.5,1.34,1.22],[19.2,22.1,2.9,1.15...       62.0    52.0
#
#        hrv_hf                                     hrv_rmssd_data  \
# 16201    85.0  [[1602087771,48,13,87,0,156],[1602087951,37,14...
# 16202    79.0  [[1602106522,25,18,82,0,206],[1602106702,25,17...
# 16203    64.0  [[1602177325,70,40,60,0,132],[1602178586,61,37...
# 16204    81.0  [[1602193181,22,25,75,0,232],[1602193361,26,22...
# 16205    82.0  [[1602279917,38,19,81,0,229],[1602280097,42,18...
# ...       ...                                                ...
# 21791    43.0  [[1677444369,17,71,29,1,72],[1677444549,18,69,...
# 21792    47.0  [[1677534034,58,65,35,1,537],[1677534214,51,58...
# 21793    45.0  [[1677616786,34,39,61,1,134],[1677616966,32,43...
# 21794    40.0  [[1677703042,20,51,49,0,91],[1677703223,21,49,...
# 21795    48.0  [[1677791437,19,44,56,0,182],[1677791617,21,42...
#
#        hrv_rmssd_evening  hrv_rmssd_morning  temp_v1_uid  patient_ID  AGEBL  \
# 16201               36.5               33.5          NaN         431   76.0
# 16202               55.4               51.9          NaN         431   76.0
# 16203               67.0               35.3          NaN         431   76.0
# 16204               43.2                4.7          NaN         431   76.0
# 16205               52.4               30.4          NaN         431   76.0
# ...                  ...                ...          ...         ...    ...
# 21791               26.5               25.6          NaN         554   74.0
# 21792               31.2               24.2          NaN         554   74.0
# 21793               36.2               15.7          NaN         554   74.0
# 21794               28.2               17.7          NaN         554   74.0
# 21795               19.0               25.6          NaN         554   74.0
#
#        GENDER  NYHABL  EFTITBL  EJREHABBL  EJFINISHBL  WEIGHTBL  HEIGHTBL  \
# 16201     0.0     2.0     30.0       35.0        35.0      74.1     192.0
# 16202     0.0     2.0     30.0       35.0        35.0      74.1     192.0
# 16203     0.0     2.0     30.0       35.0        35.0      74.1     192.0
# 16204     0.0     2.0     30.0       35.0        35.0      74.1     192.0
# 16205     0.0     2.0     30.0       35.0        35.0      74.1     192.0
# ...       ...     ...      ...        ...         ...       ...       ...
# 21791     0.0     2.0     20.0        NaN         NaN      74.0     183.0
# 21792     0.0     2.0     20.0        NaN         NaN      74.0     183.0
# 21793     0.0     2.0     20.0        NaN         NaN      74.0     183.0
# 21794     0.0     2.0     20.0        NaN         NaN      74.0     183.0
# 21795     0.0     2.0     20.0        NaN         NaN      74.0     183.0
#
#        BPSYSBL  BPDIABL   HRB
# 16201    130.0     45.0  59.0
# 16202    130.0     45.0  59.0
# 16203    130.0     45.0  59.0
# 16204    130.0     45.0  59.0
# 16205    130.0     45.0  59.0
# ...        ...      ...   ...
# 21791    116.0     72.0  74.0
# 21792    116.0     72.0  74.0
# 21793    116.0     72.0  74.0
# 21794    116.0     72.0  74.0
# 21795    116.0     72.0  74.0
#
# [5595 rows x 53 columns]
